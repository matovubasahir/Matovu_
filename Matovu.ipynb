# %% [markdown]
# <a href="https://colab.research.google.com/github/matovubasahir/Matovu_/blob/main/Matovu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Copy of Class I & II.ipynb_

print("Hello, World!") #string

Hello, World!

a = 10
b = "Hello, World!"
print(a)
print(b)

10
Hello, World!

Python as a calculator

#sum #python operators


7 + 7

14

12 + 12

24

10 + 10

20

8 + 8

16

2 + 2

4

7/4

1.75

7 % 3

1

7 / 3

2.3333333333333335

7 - 3

4

2 * 3

6

2 ** 3 #(2*2*2)

8

 2 / 3

0.6666666666666666

2 // 3

0

0.1 + 0.2

0.30000000000000004

0.3 - 0.3

0.0

0.1 + 0.2 - 0.3

5.551115123125783e-17

# variables

#intergers - whole numbers
#float - decimal
#strings - characters


my_oranges = 10

print(my_oranges)

10

print(10)

10

my_dogs = 2 #variables
print(my_dogs)

2

#strings

my_name = "Bashir"

print(my_name)

Bashir

class_name = "Auntie Claire's Python Class"
print(class_name)

Auntie Claire's Python Class

#variable

my_dogs = 2
print(my_dogs)

2

print(type(my_dogs))

<class 'int'>

my_dogs = 0.9

print(my_dogs)

0.9

print(type(my_dogs))

<class 'float'>

my_dogs = "Sammy","Frankie"

print(my_dogs)

('Sammy', 'Frankie')

# strings

# list []

my_dogs = ['Sammy', 'Frankie']

print(my_dogs)

['Sammy', 'Frankie']

my_dogs = ['Sammy', 'Frankie']
print(my_dogs)

['Sammy', 'Frankie']

print(type(my_dogs))

<class 'list'>

print(type(my_dogs))

<class 'list'>

my_dogs = 2
print(type(my_dogs))

<class 'int'>

#String index positive

#H - 0
#e - 1
#l - 2
#l - 3
#o - 4

#reverse index - negative

#o - -1

character = "Hello"


print(character[-3])

l

#reverse index

character = "Hello"
print(character[-4])

e

#silcing [::]

#[0:4] Start from 0 to 4

#[::] Start from begining to end

character = "Hello"
print(character[::]) #starting from begining to end

Hello

character = "Hello"
print(character[2:])  #starting from 2 to the end

llo

character = "Hello"
print(character[:2]) #starting from begining to 2

He

character = "Hello"
print(character[1:3]) #starting from 1 to 3 middle

el

#silcing [Start:End:Step]

character = "Hello"

print(character[::2]) #starting from begining to end with step 2

Hlo

character = "Hello"
print(character[::-1]) #reverse string

olleH

Double-click (or enter) to edit

*HOME WORK *

    Print the name of your school
    Print three words let each word be on its own line
    Use len to give me the size of the word ‘anaconda’

B. String Slicing Use string slicing to grab the word ink from inside tinker For example ‘education’[3:6] returns ‘cat’ Remember that when slicing you only go up to but not including the end index

You should only write one line of code for this. Do not assign a variable name to the string

C. String Indexing Write a string index that returns just the letter ‘r’ from ‘Hello World’

For example ‘Hello World’[0] returns ‘H’

You should only write one line of code for this. Do not assign a variable name to the string

#strings

school_name = "kalinabiri secondary school"

print(school_name)

kalinabiri secondary school

school_name = "kalinabiri"

print(school_name)

kalinabiri

school_name = "secondary"

print(school_name)

secondary

school_name = "school"

print(school_name)

school

# %%
Copy of Class I & II.ipynb_

print("Hello, World!") #string

Hello, World!

a = 10
b = "Hello, World!"
print(a)
print(b)

10
Hello, World!

Python as a calculator

#sum #python operators


7 + 7

14

12 + 12

24

10 + 10

20

8 + 8

16

2 + 2

4

7/4

1.75

7 % 3

1

7 / 3

2.3333333333333335

7 - 3

4

2 * 3

6

2 ** 3 #(2*2*2)

8

 2 / 3

0.6666666666666666

2 // 3

0

0.1 + 0.2

0.30000000000000004

0.3 - 0.3

0.0

0.1 + 0.2 - 0.3

5.551115123125783e-17

# variables

#intergers - whole numbers
#float - decimal
#strings - characters


my_oranges = 10

print(my_oranges)

10

print(10)

10

my_dogs = 2 #variables
print(my_dogs)

2

#strings

my_name = "Bashir"

print(my_name)

Bashir

class_name = "Auntie Claire's Python Class"
print(class_name)

Auntie Claire's Python Class

#variable

my_dogs = 2
print(my_dogs)

2

print(type(my_dogs))

<class 'int'>

my_dogs = 0.9

print(my_dogs)

0.9

print(type(my_dogs))

<class 'float'>

my_dogs = "Sammy","Frankie"

print(my_dogs)

('Sammy', 'Frankie')

# strings

# list []

my_dogs = ['Sammy', 'Frankie']

print(my_dogs)

['Sammy', 'Frankie']

my_dogs = ['Sammy', 'Frankie']
print(my_dogs)

['Sammy', 'Frankie']

print(type(my_dogs))

<class 'list'>

print(type(my_dogs))

<class 'list'>

my_dogs = 2
print(type(my_dogs))

<class 'int'>

#String index positive

#H - 0
#e - 1
#l - 2
#l - 3
#o - 4

#reverse index - negative

#o - -1

character = "Hello"


print(character[-3])

l

#reverse index

character = "Hello"
print(character[-4])

e

#silcing [::]

#[0:4] Start from 0 to 4

#[::] Start from begining to end

character = "Hello"
print(character[::]) #starting from begining to end

Hello

character = "Hello"
print(character[2:])  #starting from 2 to the end

llo

character = "Hello"
print(character[:2]) #starting from begining to 2

He

character = "Hello"
print(character[1:3]) #starting from 1 to 3 middle

el

#silcing [Start:End:Step]

character = "Hello"

print(character[::2]) #starting from begining to end with step 2

Hlo

character = "Hello"
print(character[::-1]) #reverse string

olleH

Double-click (or enter) to edit

*HOME WORK *

    Print the name of your school
    Print three words let each word be on its own line
    Use len to give me the size of the word ‘anaconda’

B. String Slicing Use string slicing to grab the word ink from inside tinker For example ‘education’[3:6] returns ‘cat’ Remember that when slicing you only go up to but not including the end index

You should only write one line of code for this. Do not assign a variable name to the string

C. String Indexing Write a string index that returns just the letter ‘r’ from ‘Hello World’

For example ‘Hello World’[0] returns ‘H’

You should only write one line of code for this. Do not assign a variable name to the string

#strings

school_name = "kalinabiri secondary school"

print(school_name)

kalinabiri secondary school

school_name = "kalinabiri"

print(school_name)

kalinabiri

school_name = "secondary"

print(school_name)

secondary

school_name = "school"

print(school_name)

school
# Out:
# anconda

# %%
#silicing [::]

character = ("education")

print(character[3:6])
# Out:
# cat

# %%
#silicing [start:End:step]

chaaracter = "Hello world"
print(character[8:9])
# Out:
# r

# %%
#silicing [start:End:step]

character = "Hello World"
print(character[-11])
# Out:
# H
